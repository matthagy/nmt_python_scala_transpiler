# %% [markdown]
# # Python to Scala Transpiler using Neural Machine Translation
# This project demonstrates how to convert simple Python expressions into Scala expressions. For example, consider the following Python expression.
# ```python
# [a(x, z) for x in l if b(x, y)]
# ```
# Within the context of this work, the equivalent Scala expressions is
# ```scala
# l.filter(x => b(x, y)).map(x => a(x, z))
# ```
#
# [Neural machine translation (NMT)](https://en.wikipedia.org/wiki/Neural_machine_translation)
# is applied using a [recurrent neural network](https://en.wikipedia.org/wiki/Recurrent_neural_network)
# to implement this transpiler. The RNN is created by adapting the excellent work of Zafarali Ahmed in
# [keras-attention](https://github.com/datalogue/keras-attention),
# which was originally developed to convert dates from varied human readable format to machine format.
#
# For a discussion of results, see the corresponding blog post, [A Python to Scala transpiler using neural machine translation (NMT)](https://medium.com/@matthagy/a-python-to-scala-transpiler-using-neural-machine-translation-nmt-90d4d02afa70).
#
# See README.md for more details on this work and reproducing and extending it.

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm import tqdm

import tensorflow as tf
from keras.callbacks import ModelCheckpoint
from keras.utils.training_utils import multi_gpu_model
# Out:
# Using TensorFlow backend.

# %%
# include companion project keras-attention libraries
import sys
sys.path.append('../keras-attention')

from data.reader import Vocabulary, Data
from models.NMT import simpleNMT
from utils.metrics import all_acc

# %% [markdown]
# # Load Data
# See details in README.md for generating data

# %%
expressions = pd.read_csv('data/expressions', sep='|', names=['python', 'scala'])
expressions = expressions.rename(columns={'python':'input', 'scala':'output'})
print(len(expressions))

expressions.sample(8)
# Out:
# 400000
#                                                     input  \
# 163704     [z(j) for j in m(g(t),[d for d in t if j(d)])]
# 216160                                [m(f,b) for f in c]
# 317981  [j(k) for k in q(y(q,v),[q(v,f(z(g(k),v(q)),j(...
# 194187                             [b for b in c if b(b)]
# 266994                     [p(b) for b in o(i,x(b)) if b]
# 55682                                           e(u,h(u))
# 119073        [f for f in k([u(r) for r in l],u(l)) if f]
# 298186                             [c(r(j),u) for u in z]
#
#                                                    output
# 163704                         m(g(t),t.filter(j)).map(z)
# 216160                                 c.map(f => m(f,b))
# 317981  q(y(q,v),q.filter(v => v).map(v => q(v,f(z(g(k...
# 194187                                        c.filter(b)
# 266994                    o(i,x(b)).filter(b => b).map(p)
# 55682                                           e(u,h(u))
# 119073                    k(l.map(u),u(l)).filter(f => f)
# 298186                              z.map(u => c(r(j),u))

# %% [markdown]
# ## Determine Padding Size

# %%
max_input_length = expressions['input'].str.len().max()
max_input_length
# Out:
# 278

# %%
max_output_length = expressions['output'].str.len().max()
max_output_length
# Out:
# 282

# %%
padding = max(max_input_length, max_output_length) + 16
padding
# Out:
# 298

# %%
class ExpressionVocabulary(Vocabulary):
    """Hacked class to expose the vecabularly using an API required by keras-attention
       for data in this project.
    """
    
    def __init__(self, vocabulary, padding):
        self.vocabulary = vocabulary
        self.padding = padding
        self.reverse_vocabulary = {v: k for k, v in self.vocabulary.items()}
        
    @classmethod
    def from_strings(cls, strs, padding):
        strs = list(strs)
        chars = sorted({c for s in strs for c in s})
        chars = chars + ['<unk>', '<eof>']
        return cls({c:i for i,c in enumerate(chars)}, padding)

# %%
input_vocab = ExpressionVocabulary.from_strings(expressions['input'], padding)
input_vocab.size()
# Out:
# 34

# %%
output_vocab = ExpressionVocabulary.from_strings(expressions['output'], padding)
output_vocab.size()
# Out:
# 35

# %%
class ExpressionData(Data):
    """Hacked class to expose the expressions using an API required by keras-attention
       for data in this project.
    """
    
    def __init__(self, inputs, targets, input_vocabulary, output_vocabulary):
        self.inputs = list(inputs)
        self.targets = list(targets)
        self.input_vocabulary = input_vocabulary
        self.output_vocabulary = output_vocabulary

# %%
training_size = int(0.8 * len(expressions))
training_size
# Out:
# 320000

# %%
training = ExpressionData(
    expressions['input'].iloc[:training_size],
    expressions['output'].iloc[:training_size],
    input_vocab,
    output_vocab
)
training.transform()

# %%
validation = ExpressionData(
    expressions['input'].iloc[training_size:],
    expressions['output'].iloc[training_size:],
    input_vocab,
    output_vocab
)
validation.transform()

# %% [markdown]
# ## Create the NMT model using keras-attention

# %%
model = simpleNMT(pad_length=padding,
              n_chars=input_vocab.size(),
              n_labels=output_vocab.size(),
              embedding_learnable=False,
              encoder_units=512,
              decoder_units=512,
              trainable=True,
              return_probabilities=False)
# Out:
# inputs shape: (?, ?, 1024)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 298)               0
# _________________________________________________________________
# OneHot (Embedding)           (None, 298, 34)           1156
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 298, 1024)         2240512
# _________________________________________________________________
# attention_decoder_1 (Attenti (None, 298, 35)           3781356
# =================================================================
# Total params: 6,023,024
# Trainable params: 6,021,868
# Non-trainable params: 1,156
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', all_acc])

# %% [markdown]
# ## Model Training

# %%
def train_cycle():
    cp = ModelCheckpoint("./data/weights/NMT.{epoch:02d}-{val_loss:.2f}.hdf5",
                         monitor='val_loss',
                         verbose=0,
                         save_best_only=True,
                         save_weights_only=True,
                         mode='auto')

    batch_size = 10
    model.fit_generator(generator=training.generator(batch_size),
                        steps_per_epoch=100,
                        validation_data=validation.generator(batch_size),
                        validation_steps=100,
                        callbacks=[cp],
                        workers=1,
                        verbose=1,
                        epochs=5)

# %% [markdown]
# ## Show Examples of Model on Validation Input

# %%
def encode(input_string):
    "Convert an input string in an array of numbers, on which modeling can be applied"
    return np.array([input_vocab.string_to_int(input_string)])

def apply_model(input_string):
    "Run the model on a single input string"
    full_prediction = model.predict(encode(input_string))
    prediction = np.argmax(full_prediction[0], axis=-1)
    return output_vocab.int_to_string(prediction)
    
def show_example_ml_application(input_string):
    "Interpret the terminal and padding characters in raw results"
    results = apply_model(input_string)
    pretty = ''.join('|' if x=='<eot>' else ('' if x == '<unk>' else x)
                     for x in results)
    print(repr(input_string), '->', repr(pretty))
    

examples = list(expressions['input'].iloc[training_size:].sample(10))

def show_examples():
    for example in examples:
        show_example_ml_application(example)

# %% [markdown]
# # Train and Show Examples Loop

# %%
for i in range(100000):
    print('cycle', i)
    train_cycle()
    show_examples()
    print('-'*80)
# Out:
# cycle 0
# Epoch 1/5
# 100/100 [==============================] - 305s 3s/step - loss: 0.3820 - acc: 0.9250 - all_acc: 0.0000e+00 - val_loss: 0.2383 - val_acc: 0.9398 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2472 - acc: 0.9366 - all_acc: 0.0000e+00 - val_loss: 0.2193 - val_acc: 0.9428 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2250 - acc: 0.9417 - all_acc: 0.0000e+00 - val_loss: 0.2067 - val_acc: 0.9451 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2053 - acc: 0.9453 - all_acc: 0.0000e+00 - val_loss: 0.2003 - val_acc: 0.9449 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2039 - acc: 0.9451 - all_acc: 0.0000e+00 - val_loss: 0.2219 - val_acc: 0.9443 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'c(f(.)er(. (>(. (p(.((p))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'c(f).tel)er(>(. ()'
# '[l(n) for n in o]' -> 'a.map('
# '[p for p in n if b(p)]' -> 'f.filter(e ('
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'c(f(.(,)(.)())))()(((((((((((()))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'c(f).ter(e (>(.))))'
# '[a(e,c) for e in b]' -> 'a.ma.((p(p))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'c(f(.(,)(.)())))()(((((((((((((())))))))'
# '[i(c,z) for z in t if z]' -> 'c(m).ter(. (>(p)))))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'c(f(.)il).)(>(. (p(.)()))))'
# --------------------------------------------------------------------------------
# cycle 1
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1856 - acc: 0.9486 - all_acc: 0.0000e+00 - val_loss: 0.1965 - val_acc: 0.9449 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1748 - acc: 0.9514 - all_acc: 0.0000e+00 - val_loss: 0.1938 - val_acc: 0.9489 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1915 - acc: 0.9493 - all_acc: 0.0000e+00 - val_loss: 0.1772 - val_acc: 0.9512 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 302s 3s/step - loss: 0.1887 - acc: 0.9497 - all_acc: 0.0000e+00 - val_loss: 0.1806 - val_acc: 0.9510 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1832 - acc: 0.9496 - all_acc: 0.0000e+00 - val_loss: 0.1635 - val_acc: 0.9550 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'd(f(l)er(e => p(=(((((()))))'
# '[d for d in p(e,e) if t(s,d)]' -> '(f(l)ifilter(e '
# '[l(n) for n in o]' -> 'm.map(a)'
# '[p for p in n if b(p)]' -> 't.filter(e => '
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 't(f(q(,((((((((((((((((((((((((((((((((())))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 't(f(l),)i.)er)e)=> )'
# '[a(e,c) for e in b]' -> 'm.map(a => =( (,)))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 't(f(q(,(((((((((((((((((((((((((((((((((((((())))))))))'
# '[i(c,z) for z in t if z]' -> 'm(filter(. => p(=( (()))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 't(f(l),)).)ir).)ap .)'
# --------------------------------------------------------------------------------
# cycle 2
# Epoch 1/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1680 - acc: 0.9546 - all_acc: 0.0000e+00 - val_loss: 0.1565 - val_acc: 0.9574 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1539 - acc: 0.9586 - all_acc: 0.0000e+00 - val_loss: 0.1868 - val_acc: 0.9495 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1605 - acc: 0.9558 - all_acc: 0.0000e+00 - val_loss: 0.1522 - val_acc: 0.9587 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1470 - acc: 0.9607 - all_acc: 0.0000e+00 - val_loss: 0.1587 - val_acc: 0.9605 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1571 - acc: 0.9584 - all_acc: 0.0000e+00 - val_loss: 0.1629 - val_acc: 0.9558 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'q.map(e => =( (((((((((())))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'a(d(.).filter(e => '
# '[l(n) for n in o]' -> 'o.map(z)'
# '[p for p in n if b(p)]' -> 'e(f).ter(e)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'k(g(q(,))))))))))))))))))(((((((()))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'g(g(q(,(,))))).)).).)(.'
# '[a(e,c) for e in b]' -> 'o.map(s => p(g,,))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'k(g(l),))))))))))) ((((((((((((((((((((())))))))'
# '[i(c,z) for z in t if z]' -> 'e.filter(e => p).map(t => p(.,a)'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'g(g(q(,(,)))))))))))))p)a))'
# --------------------------------------------------------------------------------
# cycle 3
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1295 - acc: 0.9657 - all_acc: 0.0000e+00 - val_loss: 0.1328 - val_acc: 0.9639 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1610 - acc: 0.9569 - all_acc: 0.0000e+00 - val_loss: 0.1486 - val_acc: 0.9598 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1403 - acc: 0.9627 - all_acc: 0.0000e+00 - val_loss: 0.1436 - val_acc: 0.9613 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1430 - acc: 0.9621 - all_acc: 0.0000e+00 - val_loss: 0.1274 - val_acc: 0.9663 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 303s 3s/step - loss: 0.1391 - acc: 0.9627 - all_acc: 0.0000e+00 - val_loss: 0.1313 - val_acc: 0.9643 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'q.ma.tar(> => ((((((((((())))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'm(e).f.filter(= => d(d,))'
# '[l(n) for n in o]' -> 'o.map(h)'
# '[p for p in n if b(p)]' -> 'j.filter(h)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'i(f(m(,)(.)=((. (( .((((((((((((((((((())))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(e(m).filter(a).map()'
# '[a(e,c) for e in b]' -> 'i.map(l => a(h,g))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'i(f(m(,)(. =( . (( ((((((((((((((((((((())))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 'i.filter(m => m).map(v => h(z,v))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'm(e(m(,)())))).)).).pap('
# --------------------------------------------------------------------------------
# cycle 4
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1397 - acc: 0.9632 - all_acc: 0.0000e+00 - val_loss: 0.1173 - val_acc: 0.9685 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1529 - acc: 0.9592 - all_acc: 0.0000e+00 - val_loss: 0.1337 - val_acc: 0.9648 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1194 - acc: 0.9683 - all_acc: 0.0000e+00 - val_loss: 0.1394 - val_acc: 0.9623 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1200 - acc: 0.9677 - all_acc: 0.0000e+00 - val_loss: 0.1315 - val_acc: 0.9650 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1272 - acc: 0.9657 - all_acc: 0.0000e+00 - val_loss: 0.1494 - val_acc: 0.9596 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(m(p(a(((((((((((((,,)))))'
# '[d for d in p(e,e) if t(s,d)]' -> 's(p(.),)).filte => =(,'
# '[l(n) for n in o]' -> 'n.map(i)'
# '[p for p in n if b(p)]' -> 'g.filter(p)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'p(s(p(,((((((()(((((((((((((((((((((((()))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 's(s(u),f).filter(p).m'
# '[a(e,c) for e in b]' -> 'b.map(b => (b,b))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'p(s(p(,((((((()()))))()()(((((((((((((((((()))))'
# '[i(c,z) for z in t if z]' -> 'z.map(z => =(z,z(,))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 's(s(q),(())))).)(p(.m'
# --------------------------------------------------------------------------------
# cycle 5
# Epoch 1/5
# 100/100 [==============================] - 302s 3s/step - loss: 0.1236 - acc: 0.9663 - all_acc: 0.0000e+00 - val_loss: 0.1254 - val_acc: 0.9665 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1240 - acc: 0.9660 - all_acc: 0.0000e+00 - val_loss: 0.1164 - val_acc: 0.9693 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1165 - acc: 0.9684 - all_acc: 0.0000e+00 - val_loss: 0.1348 - val_acc: 0.9658 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1143 - acc: 0.9687 - all_acc: 0.0000e+00 - val_loss: 0.1076 - val_acc: 0.9701 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1139 - acc: 0.9689 - all_acc: 0.0000e+00 - val_loss: 0.1146 - val_acc: 0.9675 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k)l(k (> => (((((((((((((((,)))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(p,p),)).ter(e => t())'
# '[l(n) for n in o]' -> 'o.map(n)'
# '[p for p in n if b(p)]' -> 'b.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'k(k(q(q)((),))))))              ((((((((()))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'd(d(d),)).filter(l).map('
# '[a(e,c) for e in b]' -> 'b.map(e => e(e,c),'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(n(l(e)(e)=)((((((((((((((((((((((((((((((((((((((((()))))))))'
# '[i(c,z) for z in t if z]' -> 'z.filter(z => z).map(z => c(c,))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'a(a(a(,)(y),y).mapmppp'
# --------------------------------------------------------------------------------
# cycle 6
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0996 - acc: 0.9718 - all_acc: 0.0000e+00 - val_loss: 0.0912 - val_acc: 0.9735 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0814 - acc: 0.9765 - all_acc: 0.0000e+00 - val_loss: 0.0934 - val_acc: 0.9734 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0977 - acc: 0.9717 - all_acc: 0.0000e+00 - val_loss: 0.0905 - val_acc: 0.9743 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1217 - acc: 0.9689 - all_acc: 0.0000e+00 - val_loss: 0.2086 - val_acc: 0.9473 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.3951 - acc: 0.9312 - all_acc: 0.0000e+00 - val_loss: 0.2536 - val_acc: 0.9406 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'p.f,lfirte)=> '
# '[d for d in p(e,e) if t(s,d)]' -> 'o.fi.fir(e)'
# '[l(n) for n in o]' -> 'o(n).ma'
# '[p for p in n if b(p)]' -> 'o.filter(e)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(f,.)ir(e)=> )'
# '[v(r) for r in m(d,y) if l(r)]' -> 'o.f,.fir(e)'
# '[a(e,c) for e in b]' -> 'o.filter(e)'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'p(f,l)irte)= '
# '[i(c,z) for z in t if z]' -> 'o.fi.fi)(e)'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'p(f,.)i)(e) '
# --------------------------------------------------------------------------------
# cycle 7
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2070 - acc: 0.9473 - all_acc: 0.0000e+00 - val_loss: 0.2089 - val_acc: 0.9435 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1964 - acc: 0.9459 - all_acc: 0.0000e+00 - val_loss: 0.1894 - val_acc: 0.9477 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1842 - acc: 0.9491 - all_acc: 0.0000e+00 - val_loss: 0.1812 - val_acc: 0.9496 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1730 - acc: 0.9521 - all_acc: 0.0000e+00 - val_loss: 0.1710 - val_acc: 0.9530 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1529 - acc: 0.9572 - all_acc: 0.0000e+00 - val_loss: 0.1588 - val_acc: 0.9552 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k,k(i)(. (k(. => ,(=( ,(((),))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'e(f,.(i)te => =( ,))'
# '[l(n) for n in o]' -> 'o.m).(i'
# '[p for p in n if b(p)]' -> 'h.filter(p)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(.(,(((),((,((((,((((((((((()()))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'y(m,.)imt.mal(.m=>()'
# '[a(e,c) for e in b]' -> 'b.map(e (> '
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(f,l(ilte (((( i((((i()())))))))))))'
# '[i(c,z) for z in t if z]' -> 'f.filter(z => z).map()'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'y(y,y(ypyp)yp(p(yp(p))p)p)'
# --------------------------------------------------------------------------------
# cycle 8
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1503 - acc: 0.9585 - all_acc: 0.0000e+00 - val_loss: 0.1425 - val_acc: 0.9597 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1474 - acc: 0.9596 - all_acc: 0.0000e+00 - val_loss: 0.1331 - val_acc: 0.9628 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1337 - acc: 0.9633 - all_acc: 0.0000e+00 - val_loss: 0.1274 - val_acc: 0.9644 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1329 - acc: 0.9636 - all_acc: 0.0000e+00 - val_loss: 0.1196 - val_acc: 0.9669 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1305 - acc: 0.9636 - all_acc: 0.0000e+00 - val_loss: 0.1089 - val_acc: 0.9696 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k,.).)). er(> => s(s,s(s))))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'e(e,e)ef)eter(e => d(d,d))'
# '[l(n) for n in o]' -> 'o.o).map'
# '[p for p in n if b(p)]' -> 'i.filter(p)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q(,()(f,)).f))).)(( (((( (((((())))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'y(y,y).m).ter(e => p(,r)'
# '[a(e,c) for e in b]' -> 'b.map(e => (,)'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(i(.)i)tef(>)e i>)e (> ((() ))))))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(a => (,))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'y(y,y),))p),p)pp(p(pp(p(ppp'
# --------------------------------------------------------------------------------
# cycle 9
# Epoch 1/5
# 100/100 [==============================] - 302s 3s/step - loss: 0.1101 - acc: 0.9697 - all_acc: 0.0000e+00 - val_loss: 0.1073 - val_acc: 0.9699 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1080 - acc: 0.9701 - all_acc: 0.0000e+00 - val_loss: 0.1345 - val_acc: 0.9626 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1127 - acc: 0.9693 - all_acc: 0.0000e+00 - val_loss: 0.1171 - val_acc: 0.9672 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0897 - acc: 0.9751 - all_acc: 0.0000e+00 - val_loss: 0.1097 - val_acc: 0.9699 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0941 - acc: 0.9742 - all_acc: 0.0000e+00 - val_loss: 0.0983 - val_acc: 0.9731 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k).map(s => h(s(s(s(s)))))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'e(e,e),filter(d => d(d,d))'
# '[l(n) for n in o]' -> 'o.o).map()'
# '[p for p in n if b(p)]' -> 'n.filter(p)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q(,(,())))))))))))))))))))))))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'y(m,y).milter(l)map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(a,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 't(a).)i)).ri) )ma)(( (( )))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(c => c(c,c))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'y(y(y(,(,y),))ppap(ppp'
# --------------------------------------------------------------------------------
# cycle 10
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0900 - acc: 0.9750 - all_acc: 0.0000e+00 - val_loss: 0.0881 - val_acc: 0.9754 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0905 - acc: 0.9751 - all_acc: 0.0000e+00 - val_loss: 0.1041 - val_acc: 0.9715 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0782 - acc: 0.9785 - all_acc: 0.0000e+00 - val_loss: 0.0827 - val_acc: 0.9769 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0892 - acc: 0.9756 - all_acc: 0.0000e+00 - val_loss: 0.0893 - val_acc: 0.9753 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0838 - acc: 0.9772 - all_acc: 0.0000e+00 - val_loss: 0.0783 - val_acc: 0.9781 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k).map(s => h(d(k(k(k(k)))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e,e)efilter(d => t(d,d))'
# '[l(n) for n in o]' -> 'o.map(a)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q(qqqqqq)))))zr()(zr() ( (( ((()()))))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(a,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 't(i).)i)(er(> =( ,((j(((()())))))))))))))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(z => c(c,c))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a(y(,(,y),y)y))p)pp(p(pp'
# --------------------------------------------------------------------------------
# cycle 11
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0835 - acc: 0.9772 - all_acc: 0.0000e+00 - val_loss: 0.0884 - val_acc: 0.9757 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0802 - acc: 0.9779 - all_acc: 0.0000e+00 - val_loss: 0.0785 - val_acc: 0.9786 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0840 - acc: 0.9776 - all_acc: 0.0000e+00 - val_loss: 0.0775 - val_acc: 0.9787 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0770 - acc: 0.9788 - all_acc: 0.0000e+00 - val_loss: 0.0882 - val_acc: 0.9764 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0811 - acc: 0.9779 - all_acc: 0.0000e+00 - val_loss: 0.0649 - val_acc: 0.9821 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k).map(s => h(d(s(k(,(,,,,,)))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e,e).filter(d => t(s,d))'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(k(q(qqqq(q),q)))f.)a.(.)a.(.,()(.(()(((()())()('
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e)(e,))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 't(t).filter(c).(ap(( => ,((,((,((())))))))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(c)'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a(y(y(,y,y),y).p)pppp(ppp'
# --------------------------------------------------------------------------------
# cycle 12
# Epoch 1/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0814 - acc: 0.9780 - all_acc: 0.0000e+00 - val_loss: 0.0688 - val_acc: 0.9817 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0781 - acc: 0.9783 - all_acc: 0.0000e+00 - val_loss: 0.0787 - val_acc: 0.9775 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.2648 - acc: 0.9460 - all_acc: 0.0000e+00 - val_loss: 0.1974 - val_acc: 0.9464 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1946 - acc: 0.9483 - all_acc: 0.0000e+00 - val_loss: 0.1655 - val_acc: 0.9550 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1617 - acc: 0.9566 - all_acc: 0.0000e+00 - val_loss: 0.1604 - val_acc: 0.9578 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(s,k),m)s((s(s(s((s(s('
# '[d for d in p(e,e) if t(s,d)]' -> 'p(f,d),fie)ed d>d'
# '[l(n) for n in o]' -> 'o.map(a)( '
# '[p for p in n if b(p)]' -> 'n.filter(p => p'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q(qq,q)qq)q)q))q)q))))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,b).mi.m(r(= ='
# '[a(e,c) for e in b]' -> 'b.map(a => '
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(n(n(,(i.).)).)())(((((((((())))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 'i.filter(p => > '
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a,y),f,p(ep(p pp(ppp'
# --------------------------------------------------------------------------------
# cycle 13
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1813 - acc: 0.9516 - all_acc: 0.0000e+00 - val_loss: 0.1853 - val_acc: 0.9467 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.1795 - acc: 0.9488 - all_acc: 0.0000e+00 - val_loss: 0.1514 - val_acc: 0.9566 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1571 - acc: 0.9554 - all_acc: 0.0000e+00 - val_loss: 0.1405 - val_acc: 0.9610 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1388 - acc: 0.9611 - all_acc: 0.0000e+00 - val_loss: 0.1420 - val_acc: 0.9592 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1269 - acc: 0.9640 - all_acc: 0.0000e+00 - val_loss: 0.1176 - val_acc: 0.9669 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k).map(k => k(h,a((((()))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e(e)efieterter(r => )'
# '[l(n) for n in o]' -> 'o.map(n)'
# '[p for p in n if b(p)]' -> 'n.filter(p).p p('
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q(q(q),)))q))))q))))q))))))))))))))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'd(d(y).filter(e)=m v(.m(p)v)'
# '[a(e,c) for e in b]' -> 'b.map(a => a(a,a))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(e(.(e((())(((((()(()((())(((())))))))))))))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 'f.filter(z => p).map(c)))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'a(a(x(,)(),,)).))p).p(p)pp(p)pp'
# --------------------------------------------------------------------------------
# cycle 14
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1254 - acc: 0.9651 - all_acc: 0.0000e+00 - val_loss: 0.1122 - val_acc: 0.9677 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1122 - acc: 0.9691 - all_acc: 0.0000e+00 - val_loss: 0.1176 - val_acc: 0.9678 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1072 - acc: 0.9708 - all_acc: 0.0000e+00 - val_loss: 0.1044 - val_acc: 0.9714 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.1008 - acc: 0.9717 - all_acc: 0.0000e+00 - val_loss: 0.1217 - val_acc: 0.9676 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0989 - acc: 0.9728 - all_acc: 0.0000e+00 - val_loss: 0.0983 - val_acc: 0.9730 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k).map(k => h(s,s()))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'e(e,e).filter(d => d(,'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(q(q)q),q(q),qf,ff.f))).)))).))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'd(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(c,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(n).fil(e(((())).)))).)))))))))))))))))))'
# '[i(c,z) for z in t if z]' -> 'f.filter(z => z).map(c)=> (,'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'a(a(y),),y,y),y),y).map(p)'
# --------------------------------------------------------------------------------
# cycle 15
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0878 - acc: 0.9757 - all_acc: 0.0000e+00 - val_loss: 0.0796 - val_acc: 0.9780 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0793 - acc: 0.9783 - all_acc: 0.0000e+00 - val_loss: 0.0775 - val_acc: 0.9788 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0794 - acc: 0.9785 - all_acc: 0.0000e+00 - val_loss: 0.0752 - val_acc: 0.9791 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0824 - acc: 0.9773 - all_acc: 0.0000e+00 - val_loss: 0.1040 - val_acc: 0.9707 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0896 - acc: 0.9750 - all_acc: 0.0000e+00 - val_loss: 0.0722 - val_acc: 0.9791 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'k(k).map(k => h(d(s(k)))))))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'e(e,e).filter(d => t(t,d))'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(k(q),q)q))))))).)))).)))).)))).)))).))))())))())))()))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'd(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(a,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'n(n).),l(u())))))))))))))))))))))))))))))))))())()())())))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(z => i(c,z))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'a(a(y),y,y,y)).))p(p)pp'
# --------------------------------------------------------------------------------
# cycle 16
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0782 - acc: 0.9782 - all_acc: 0.0000e+00 - val_loss: 0.0805 - val_acc: 0.9770 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0941 - acc: 0.9754 - all_acc: 0.0000e+00 - val_loss: 0.1247 - val_acc: 0.9669 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0960 - acc: 0.9739 - all_acc: 0.0000e+00 - val_loss: 0.0816 - val_acc: 0.9776 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0918 - acc: 0.9747 - all_acc: 0.0000e+00 - val_loss: 0.0717 - val_acc: 0.9811 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0761 - acc: 0.9791 - all_acc: 0.0000e+00 - val_loss: 0.0731 - val_acc: 0.9802 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k).map(s => h(d(s(k(k)))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e,e).filter(d => s(s,d))'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(k(q),,,q,)))))).filt.r=> => >(.map(.m)()p))())'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(a,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'e(t).filter(c).map(i => j(i,e(n(,)))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(c => c(c,z))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a(y(y)(y,y)).m)pmppp)'
# --------------------------------------------------------------------------------
# cycle 17
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0772 - acc: 0.9796 - all_acc: 0.0000e+00 - val_loss: 0.0748 - val_acc: 0.9792 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0653 - acc: 0.9821 - all_acc: 0.0000e+00 - val_loss: 0.0714 - val_acc: 0.9810 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 300s 3s/step - loss: 0.0847 - acc: 0.9782 - all_acc: 0.0000e+00 - val_loss: 0.0808 - val_acc: 0.9777 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0719 - acc: 0.9807 - all_acc: 0.0000e+00 - val_loss: 0.0600 - val_acc: 0.9833 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0780 - acc: 0.9792 - all_acc: 0.0000e+00 - val_loss: 0.0662 - val_acc: 0.9823 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k).map(s => h(d(s(k)k)(k),)))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e,e).filter(s => s(s,d))'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(k(q),q(q,z))),)))z)()(z)()(=)))))))))))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,y).filter(r).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(e,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'z(t).fel(e ()(a)(i(e)())e))()))))))))))))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(z => i(c,z))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a(y(y)yy,y)).)ap)pppp(p)'
# --------------------------------------------------------------------------------
# cycle 18
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0632 - acc: 0.9832 - all_acc: 0.0000e+00 - val_loss: 0.0745 - val_acc: 0.9794 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0638 - acc: 0.9823 - all_acc: 0.0000e+00 - val_loss: 0.0503 - val_acc: 0.9857 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0648 - acc: 0.9825 - all_acc: 0.0000e+00 - val_loss: 0.0736 - val_acc: 0.9792 - val_all_acc: 0.0000e+00
# Epoch 4/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0684 - acc: 0.9817 - all_acc: 0.0000e+00 - val_loss: 0.0698 - val_acc: 0.9819 - val_all_acc: 0.0000e+00
# Epoch 5/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0693 - acc: 0.9812 - all_acc: 0.0000e+00 - val_loss: 0.0461 - val_acc: 0.9871 - val_all_acc: 0.0000e+00
# '[h(d(s(k),f(y(k),w)),s) for s in l(k)]' -> 'l(k).map(s => h(d(s(s(k)(k(k),)))))))))'
# '[d for d in p(e,e) if t(s,d)]' -> 'p(e,e).filter(d => t(s,d))'
# '[l(n) for n in o]' -> 'o.map(l)'
# '[p for p in n if b(p)]' -> 'n.filter(b)'
# '[f(q,e(p,r)) for q in q(k(q),g(r(q),z)) if j(z(z,z),q)]' -> 'q(k(q),g(r,z)).)))fi)ier(r z)z)zz(z))z))))))=> ( => ( (( ( )))))'
# '[v(r) for r in m(d,y) if l(r)]' -> 'm(d,y).filter(l).map(v)'
# '[a(e,c) for e in b]' -> 'b.map(e => a(e,c))'
# '[j(i,v([o(e) for e in z(n)],u(k(l,x(j)),n))) for i in e(t) if c(i)]' -> 'z(n).(u(t(j(xj((x())))))))))iiii( ))))))))))(((((((((((((()(()())))))'
# '[i(c,z) for z in t if z]' -> 't.filter(z => z).map(z => c(c,z))'
# '[p(p) for p in z(a(x(y),h(y,p)),y)]' -> 'z(a(y(y),y,y(,),y))pmppppppp'
# --------------------------------------------------------------------------------
# cycle 19
# Epoch 1/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0588 - acc: 0.9838 - all_acc: 0.0000e+00 - val_loss: 0.0532 - val_acc: 0.9855 - val_all_acc: 0.0000e+00
# Epoch 2/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0569 - acc: 0.9844 - all_acc: 0.0000e+00 - val_loss: 0.0569 - val_acc: 0.9844 - val_all_acc: 0.0000e+00
# Epoch 3/5
# 100/100 [==============================] - 301s 3s/step - loss: 0.0708 - acc: 0.9826 - all_acc: 0.0000e+00 - val_loss: 0.1151 - val_acc: 0.9698 - val_all_acc: 0.0000e+00
# Epoch 4/5
#  88/100 [=========================>....] - ETA: 26s - loss: 0.0713 - acc: 0.9815 - all_acc: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1e336c81ae51> in <module>()
#       1 for i in range(100000):
#       2     print('cycle', i)
# ----> 3     train_cycle()
#       4     show_examples()
#       5     print('-'*80)
#
# <ipython-input-17-620fcdad904d> in train_cycle()
#      15                         workers=1,
#      16                         verbose=1,
# ---> 17                         epochs=5)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
evaluation = expressions.iloc[training_size:].sample(200).copy()
evaluation.sample(5)
# Out:
#                                               input  \
# 358683  [a(k,u(w,p(z(k),k))) for k in i(x) if y(k)]
# 330020                                            o
# 333910       [f(q,e(y(a),s(q))) for q in t if x(q)]
# 334352                                            g
# 384249                                         q(r)
#
#                                               output
# 358683  i(x).filter(y).map(k => a(k,u(w,p(z(k),k))))
# 330020                                             o
# 333910       t.filter(x).map(q => f(q,e(y(a),s(q))))
# 334352                                             g
# 384249                                          q(r)

# %%
def apply_convert(input_string):
    results = apply_model(input_string)
    terminate = results.index('<unk>')
    return ''.join(results[:terminate:])

evaluation['results'] = [apply_convert(input_string) for input_string in tqdm(evaluation['input'])]
evaluation.sample(5)
# Out:
# 100%|██████████| 200/200 [01:41<00:00,  1.98it/s]
#                                       input                            output  \
# 376389  [o for o in o(n) if r(z(b(o),a),o)]  o(n).filter(o => r(z(b(o),a),o))
# 334148                                    t                                 t
# 328131  [e for e in r(v,i(f,q(e))) if y(e)]          r(v,i(f,q(e))).filter(y)
# 386355  [p for p in q(s,q(p,a(f))) if h(p)]          q(s,q(p,a(f))).filter(h)
# 393946         [m(b) for b in d(c) if r(b)]             d(c).filter(r).map(m)
#
#                                  results
# 376389  o(n).filter(o => r(r(o(o),)),o))
# 334148                                 t
# 328131          r(v,f(f)l(())).filter(e)
# 386355          q(s,q(q,a(f))).filter(f)
# 393946             d(c).filter(r).map(m)

# %%
np.mean(evaluation['output'] == evaluation['results'])
# Out:
# 0.565

# %%
with pd.option_context('display.max_colwidth', 200):
    display(evaluation.rename(columns={'output':'expected'}).sample(10))
# Out:
#                                                         input  \
# 398497                          [c(q(l,d),h) for h in l if h]
# 381279                                    [r for r in t if r]
# 320977                                 [x(l) for l in w(k,g)]
# 367582  [s(n,b(m,f)) for n in e(y(p(s),o(w(s),n)),s) if u(n)]
# 367794                                 [z(j,e(w)) for j in h]
# 384249                                                   q(r)
# 364872                         [x(f) for f in s(r(d(f),l),f)]
# 328018                                                      b
# 333045                                    [n for n in p if n]
# 373145                              [i(h) for h in t(i,a(h))]
#
#                                                       expected  \
# 398497                  l.filter(h => h).map(h => c(q(l,d),h))
# 381279                                        t.filter(r => r)
# 320977                                           w(k,g).map(x)
# 367582  e(y(p(s),o(w(s),n)),s).filter(u).map(n => s(n,b(m,f)))
# 367794                                   h.map(j => z(j,e(w)))
# 384249                                                    q(r)
# 364872                                   s(r(d(f),l),f).map(x)
# 328018                                                       b
# 333045                                        p.filter(n => n)
# 373145                                        t(i,a(h)).map(i)
#
#                                                    results
# 398497                l.filter(h => h).map(h => h(c,d),)))
# 381279                                    t.filter(r => r)
# 320977                                       w(k,g).map(x)
# 367582  e(y(s(s))s),((s(s(),)),filter(er(r .> )(n (> (((((
# 367794                               h.map(j => z(j,e)e)))
# 384249                                                q(r)
# 364872                    s(r(f)f),lf,lter(l => f(f,a)).ma
# 328018                                                   b
# 333045                                    p.filter(n => n)
# 373145                                    t(i,a(h)).map(i)

# %% [markdown]
# For a discussion of results, see the corresponding blog post, [A Python to Scala transpiler using neural machine translation (NMT)](https://medium.com/@matthagy/a-python-to-scala-transpiler-using-neural-machine-translation-nmt-90d4d02afa70).
